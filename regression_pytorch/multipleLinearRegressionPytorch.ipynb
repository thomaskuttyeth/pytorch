# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler    
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
def get_class_distribution(y):
    element,counts = np.unique(y,return_counts = True)
    output = dict(zip(element,counts))
    return output

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

# %%
# Train - Test
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=69)
# Split train into train-val
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1, stratify=y_trainval, random_state=21)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)
X_train, y_train = np.array(X_train), np.array(y_train)
X_val, y_val = np.array(X_val), np.array(y_val)
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
y_train, y_test, y_val = y_train.astype(float), y_test.astype(float), y_val.astype(float)

# %%
class RegressionDataset(Dataset):
    
    def __init__(self, X_data, y_data):
        self.X_data = X_data
        self.y_data = y_data
        
    def __getitem__(self, index):
        return self.X_data[index], self.y_data[index]
        
    def __len__ (self):
        return len(self.X_data)
train_dataset = RegressionDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).float())
val_dataset = RegressionDataset(torch.from_numpy(X_val).float(), torch.from_numpy(y_val).float())
test_dataset = RegressionDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test).float())

# %%
EPOCHS = 150
BATCH_SIZE = 64
LEARNING_RATE = 0.001
NUM_FEATURES = len(X.columns)

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=1)
test_loader = DataLoader(dataset=test_dataset, batch_size=1)

# %%
class MultipleRegression(nn.Module):
    def __init__(self, num_features):
        super(MultipleRegression, self).__init__()
        
        self.layer_1 = nn.Linear(num_features, 16)
        self.layer_2 = nn.Linear(16, 32)
        self.layer_3 = nn.Linear(32, 16)
        self.layer_out = nn.Linear(16, 1)
        
        self.relu = nn.ReLU()
    def forward(self, inputs):
        x = self.relu(self.layer_1(inputs))
        x = self.relu(self.layer_2(x))
        x = self.relu(self.layer_3(x))
        x = self.layer_out(x)
        return (x)
    def predict(self, test_inputs):
        x = self.relu(self.layer_1(test_inputs))
        x = self.relu(self.layer_2(x))
        x = self.relu(self.layer_3(x))
        x = self.relu(self.layer_out(x))
        return (x)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
model = MultipleRegression(NUM_FEATURES)
model.to(device)
print(model)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
# Out:
# MultipleRegression(
#   (layer_1): Linear(in_features=11, out_features=16, bias=True)
#   (layer_2): Linear(in_features=16, out_features=32, bias=True)
#   (layer_3): Linear(in_features=32, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
loss_stats = {
    'train': [],
    "val": []
}

# %%
print("Begin training.")
for e in tqdm(range(1, EPOCHS+1)):
    
    # TRAINING
    train_epoch_loss = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch.unsqueeze(1))
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch.unsqueeze(1))
            
            val_epoch_loss += val_loss.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f}')
# Out:
# Begin training.
#   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 001: | Train Loss: 33.36190 | Val Loss: 32.29803
# Epoch 002: | Train Loss: 31.64559 | Val Loss: 30.54678
# Epoch 003: | Train Loss: 29.72180 | Val Loss: 28.15735
# Epoch 004: | Train Loss: 26.35149 | Val Loss: 23.36914
# Epoch 005: | Train Loss: 19.80476 | Val Loss: 14.72430
# Epoch 006: | Train Loss: 9.86696 | Val Loss: 4.40690
# Epoch 007: | Train Loss: 2.05921 | Val Loss: 1.09134
# Epoch 008: | Train Loss: 1.10208 | Val Loss: 1.11562
# Epoch 009: | Train Loss: 0.97389 | Val Loss: 1.00233
# Epoch 010: | Train Loss: 0.93917 | Val Loss: 0.98397
# Epoch 011: | Train Loss: 0.91600 | Val Loss: 0.96214
# Epoch 012: | Train Loss: 0.89696 | Val Loss: 0.93591
# Epoch 013: | Train Loss: 0.87656 | Val Loss: 0.90791
# Epoch 014: | Train Loss: 0.85530 | Val Loss: 0.88365
# Epoch 015: | Train Loss: 0.83554 | Val Loss: 0.85003
# Epoch 016: | Train Loss: 0.80841 | Val Loss: 0.82193
# Epoch 017: | Train Loss: 0.78232 | Val Loss: 0.79064
# Epoch 018: | Train Loss: 0.75765 | Val Loss: 0.75785
# Epoch 019: | Train Loss: 0.73261 | Val Loss: 0.72833
# Epoch 020: | Train Loss: 0.70948 | Val Loss: 0.69777
# Epoch 021: | Train Loss: 0.68618 | Val Loss: 0.66980
# Epoch 022: | Train Loss: 0.66524 | Val Loss: 0.64714
# Epoch 023: | Train Loss: 0.64619 | Val Loss: 0.61733
# Epoch 024: | Train Loss: 0.62708 | Val Loss: 0.59996
# Epoch 025: | Train Loss: 0.61292 | Val Loss: 0.57827
# Epoch 026: | Train Loss: 0.59945 | Val Loss: 0.55811
# Epoch 027: | Train Loss: 0.58691 | Val Loss: 0.54628
# Epoch 028: | Train Loss: 0.57646 | Val Loss: 0.53149
# Epoch 029: | Train Loss: 0.56587 | Val Loss: 0.51850
# Epoch 030: | Train Loss: 0.55685 | Val Loss: 0.51360
# Epoch 031: | Train Loss: 0.55105 | Val Loss: 0.49940
# Epoch 032: | Train Loss: 0.54576 | Val Loss: 0.48991
# Epoch 033: | Train Loss: 0.53796 | Val Loss: 0.48629
# Epoch 034: | Train Loss: 0.53367 | Val Loss: 0.48112
# Epoch 035: | Train Loss: 0.52849 | Val Loss: 0.47311
# Epoch 036: | Train Loss: 0.52520 | Val Loss: 0.46958
# Epoch 037: | Train Loss: 0.51997 | Val Loss: 0.46347
# Epoch 038: | Train Loss: 0.51732 | Val Loss: 0.46442
# Epoch 039: | Train Loss: 0.51595 | Val Loss: 0.45771
# Epoch 040: | Train Loss: 0.51120 | Val Loss: 0.45232
# Epoch 041: | Train Loss: 0.50875 | Val Loss: 0.45272
# Epoch 042: | Train Loss: 0.50536 | Val Loss: 0.44728
# Epoch 043: | Train Loss: 0.51610 | Val Loss: 0.47114
# Epoch 044: | Train Loss: 0.50656 | Val Loss: 0.44368
# Epoch 045: | Train Loss: 0.49720 | Val Loss: 0.44232
# Epoch 046: | Train Loss: 0.49574 | Val Loss: 0.43910
# Epoch 047: | Train Loss: 0.49295 | Val Loss: 0.43565
# Epoch 048: | Train Loss: 0.49121 | Val Loss: 0.43235
# Epoch 049: | Train Loss: 0.48926 | Val Loss: 0.43110
# Epoch 050: | Train Loss: 0.49277 | Val Loss: 0.44358
# Epoch 051: | Train Loss: 0.48518 | Val Loss: 0.42611
# Epoch 052: | Train Loss: 0.48476 | Val Loss: 0.42396
# Epoch 053: | Train Loss: 0.48137 | Val Loss: 0.42267
# Epoch 054: | Train Loss: 0.47834 | Val Loss: 0.42668
# Epoch 055: | Train Loss: 0.47710 | Val Loss: 0.41984
# Epoch 056: | Train Loss: 0.47589 | Val Loss: 0.41724
# Epoch 057: | Train Loss: 0.47307 | Val Loss: 0.42424
# Epoch 058: | Train Loss: 0.47072 | Val Loss: 0.41380
# Epoch 059: | Train Loss: 0.46950 | Val Loss: 0.41202
# Epoch 060: | Train Loss: 0.46777 | Val Loss: 0.41982
# Epoch 061: | Train Loss: 0.46803 | Val Loss: 0.40913
# Epoch 062: | Train Loss: 0.46453 | Val Loss: 0.40949
# Epoch 063: | Train Loss: 0.46379 | Val Loss: 0.40823
# Epoch 064: | Train Loss: 0.46234 | Val Loss: 0.41654
# Epoch 065: | Train Loss: 0.46002 | Val Loss: 0.40218
# Epoch 066: | Train Loss: 0.45861 | Val Loss: 0.40125
# Epoch 067: | Train Loss: 0.45622 | Val Loss: 0.40362
# Epoch 068: | Train Loss: 0.45529 | Val Loss: 0.39942
# Epoch 069: | Train Loss: 0.45452 | Val Loss: 0.40095
# Epoch 070: | Train Loss: 0.45536 | Val Loss: 0.41669
# Epoch 071: | Train Loss: 0.45655 | Val Loss: 0.40055
# Epoch 072: | Train Loss: 0.44959 | Val Loss: 0.39402
# Epoch 073: | Train Loss: 0.44930 | Val Loss: 0.39483
# Epoch 074: | Train Loss: 0.44748 | Val Loss: 0.39366
# Epoch 075: | Train Loss: 0.44635 | Val Loss: 0.39211
# Epoch 076: | Train Loss: 0.44543 | Val Loss: 0.39400
# Epoch 077: | Train Loss: 0.44579 | Val Loss: 0.39880
# Epoch 078: | Train Loss: 0.44520 | Val Loss: 0.38887
# Epoch 079: | Train Loss: 0.44100 | Val Loss: 0.39197
# Epoch 080: | Train Loss: 0.44420 | Val Loss: 0.38918
# Epoch 081: | Train Loss: 0.44277 | Val Loss: 0.38772
# Epoch 082: | Train Loss: 0.44015 | Val Loss: 0.38548
# Epoch 083: | Train Loss: 0.44142 | Val Loss: 0.38951
# Epoch 084: | Train Loss: 0.44113 | Val Loss: 0.38884
# Epoch 085: | Train Loss: 0.43685 | Val Loss: 0.38511
# Epoch 086: | Train Loss: 0.43828 | Val Loss: 0.38305
# Epoch 087: | Train Loss: 0.43588 | Val Loss: 0.38512
# Epoch 088: | Train Loss: 0.43594 | Val Loss: 0.39382
# Epoch 089: | Train Loss: 0.44547 | Val Loss: 0.38263
# Epoch 090: | Train Loss: 0.43711 | Val Loss: 0.38132
# Epoch 091: | Train Loss: 0.43599 | Val Loss: 0.38166
# Epoch 092: | Train Loss: 0.43389 | Val Loss: 0.38177
# Epoch 093: | Train Loss: 0.43410 | Val Loss: 0.38148
# Epoch 094: | Train Loss: 0.43137 | Val Loss: 0.37990
# Epoch 095: | Train Loss: 0.43494 | Val Loss: 0.38266
# Epoch 096: | Train Loss: 0.43716 | Val Loss: 0.39903
# Epoch 097: | Train Loss: 0.43882 | Val Loss: 0.38080
# Epoch 098: | Train Loss: 0.43538 | Val Loss: 0.37901
# Epoch 099: | Train Loss: 0.43120 | Val Loss: 0.37817
# Epoch 100: | Train Loss: 0.43035 | Val Loss: 0.37658
# Epoch 101: | Train Loss: 0.43381 | Val Loss: 0.37675
# Epoch 102: | Train Loss: 0.42908 | Val Loss: 0.37875
# Epoch 103: | Train Loss: 0.42996 | Val Loss: 0.37654
# Epoch 104: | Train Loss: 0.42944 | Val Loss: 0.38458
# Epoch 105: | Train Loss: 0.43182 | Val Loss: 0.37583
# Epoch 106: | Train Loss: 0.42802 | Val Loss: 0.38736
# Epoch 107: | Train Loss: 0.42803 | Val Loss: 0.37677
# Epoch 108: | Train Loss: 0.42984 | Val Loss: 0.37601
# Epoch 109: | Train Loss: 0.42964 | Val Loss: 0.38216
# Epoch 110: | Train Loss: 0.43269 | Val Loss: 0.37468
# Epoch 111: | Train Loss: 0.43123 | Val Loss: 0.39321
# Epoch 112: | Train Loss: 0.42520 | Val Loss: 0.37485
# Epoch 113: | Train Loss: 0.42718 | Val Loss: 0.37548
# Epoch 114: | Train Loss: 0.42580 | Val Loss: 0.37455
# Epoch 115: | Train Loss: 0.43123 | Val Loss: 0.37729
# Epoch 116: | Train Loss: 0.42663 | Val Loss: 0.37719
# Epoch 117: | Train Loss: 0.42496 | Val Loss: 0.37350
# Epoch 118: | Train Loss: 0.42536 | Val Loss: 0.37816
# Epoch 119: | Train Loss: 0.43593 | Val Loss: 0.37336
# Epoch 120: | Train Loss: 0.42861 | Val Loss: 0.39445
# Epoch 121: | Train Loss: 0.42544 | Val Loss: 0.37227
# Epoch 122: | Train Loss: 0.42648 | Val Loss: 0.37446
# Epoch 123: | Train Loss: 0.42517 | Val Loss: 0.37174
# Epoch 124: | Train Loss: 0.42419 | Val Loss: 0.38497
# Epoch 125: | Train Loss: 0.42567 | Val Loss: 0.38302
# Epoch 126: | Train Loss: 0.42900 | Val Loss: 0.37271
# Epoch 127: | Train Loss: 0.42364 | Val Loss: 0.37701
# Epoch 128: | Train Loss: 0.42573 | Val Loss: 0.37121
# Epoch 129: | Train Loss: 0.42728 | Val Loss: 0.38696
# Epoch 130: | Train Loss: 0.42830 | Val Loss: 0.40260
# Epoch 131: | Train Loss: 0.42800 | Val Loss: 0.37511
# Epoch 132: | Train Loss: 0.42341 | Val Loss: 0.37123
# Epoch 133: | Train Loss: 0.42276 | Val Loss: 0.37194
# Epoch 134: | Train Loss: 0.42431 | Val Loss: 0.37121
# Epoch 135: | Train Loss: 0.42329 | Val Loss: 0.37075
# Epoch 136: | Train Loss: 0.42291 | Val Loss: 0.37077
# Epoch 137: | Train Loss: 0.42269 | Val Loss: 0.37927
# Epoch 138: | Train Loss: 0.42595 | Val Loss: 0.37493
# Epoch 139: | Train Loss: 0.42442 | Val Loss: 0.37041
# Epoch 140: | Train Loss: 0.43419 | Val Loss: 0.37112
# Epoch 141: | Train Loss: 0.42745 | Val Loss: 0.37020
# Epoch 142: | Train Loss: 0.42590 | Val Loss: 0.36990
# Epoch 143: | Train Loss: 0.43050 | Val Loss: 0.37645
# Epoch 144: | Train Loss: 0.42247 | Val Loss: 0.38307
# Epoch 145: | Train Loss: 0.42676 | Val Loss: 0.37837
# Epoch 146: | Train Loss: 0.42372 | Val Loss: 0.38483
# Epoch 147: | Train Loss: 0.42109 | Val Loss: 0.38052
# Epoch 148: | Train Loss: 0.44014 | Val Loss: 0.37442
# Epoch 149: | Train Loss: 0.42794 | Val Loss: 0.37239
# Epoch 150: | Train Loss: 0.42565 | Val Loss: 0.37384

# %%
y_pred_list = []
with torch.no_grad():
    model.eval()
    for X_batch, _ in test_loader:
        X_batch = X_batch.to(device)
        y_test_pred = model(X_batch)
        y_pred_list.append(y_test_pred.cpu().numpy())
y_pred_list = [a.squeeze().tolist() for a in y_pred_list]

# %%
mse = mean_squared_error(y_test, y_pred_list)
r_square = r2_score(y_test, y_pred_list)
print("Mean Squared Error :",mse)
print("R^2 :",r_square)
# Out:
# Mean Squared Error : 0.4214190979089558
# R^2 : 0.3469139229693524
